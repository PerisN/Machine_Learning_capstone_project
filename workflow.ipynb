# %% [markdown]
# EDA
#  ↓
# Train/Test Split (stratified)
#  ↓
# Preprocessing
#  ↓
# SMOTE ── only training data
#  ↓
# Model training
#  ↓
# Cross-validation / hyperparameter tuning
#  ↓
# Final evaluation on untouched test set
#  ↓
# Confusion matrix + Macro F1 + Balanced Accuracy

# %% [markdown]
#                  ORIGINAL DATA
#                       │
#                       ▼
#               Train/Test Split
#                  /         \
#                 /           \
#           Training          Test
#              │                │
#              ▼                │
#       Encode categorical      │
#              │                │
#              ▼                │
#        RobustScaler            │
#        (continuous only)      │
#              │                │
#              ▼                │
#           SMOTENC              │
#              │                │
#              ▼                │
#       Balanced Training       │
#              │                │
#              ▼                │
#            MODEL ◄─────────────┘
#              │
#              ▼
#          Predictions
#              │
#              ▼
#           Evaluation
